# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
from scipy.io import wavfile
from collections import defaultdict, Counter
from scipy import signal
import numpy as np
import librosa
import librosa.display
import random as rn
from keras.layers import Dense
from keras import Input
from keras.engine import Model
from keras.utils import to_categorical
from keras.layers import Dense, TimeDistributed, Dropout, Bidirectional, GRU, BatchNormalization, Activation, LeakyReLU, \
    LSTM, Flatten, RepeatVector, Permute, Multiply, Conv2D, MaxPooling2D

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
DATA_DIR = 'C:/Users/hartw/OneDrive/Documents/GitHub/acoustic-sensing/free-spoken-digit-dataset/recordings/'

# %%
random_file = rn.choice(os.listdir(DATA_DIR))

# %%
wav, sr = librosa.load(DATA_DIR + random_file)
print('sr:', sr)
print('wav shape:', wav.shape)
print('length:', wav.shape[0]/float(sr), 'secs')
# Out:
# sr: 22050
# wav shape: (9303,)
# length: 0.4219047619047619 secs

# %%
wav, sr = librosa.load(DATA_DIR + random_file, sr=None)
print( 'sr:', sr)
print( 'wav shape:', wav.shape)
print( 'length:', wav.shape[0]/float(sr), 'secs')
# Out:
# sr: 8000
# wav shape: (3375,)
# length: 0.421875 secs

# %%
plt.plot(wav)

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(wav)), ref=np.max)
librosa.display.specshow(D, y_axis='linear')

# %%
test_speaker = 'theo'
train_X = []
train_spectrograms = []
train_mel_spectrograms = []
train_mfccs = []
train_y = []

test_X = []
test_spectrograms = []
test_mel_spectrograms = []
test_mfccs = []
test_y = []

pad1d = lambda a, i: a[0: i] if a.shape[0] > i else np.hstack((a, np.zeros(i - a.shape[0])))
pad2d = lambda a, i: a[:, 0: i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0],i - a.shape[1]))))

for fname in os.listdir(DATA_DIR):
    try:
        if '.wav' not in fname or 'dima' in fname:
            continue
        struct = fname.split('_')
        digit = struct[0]
        speaker = struct[1]
        wav, sr = librosa.load(DATA_DIR + fname)
        padded_x = pad1d(wav, 30000)
        spectrogram = np.abs(librosa.stft(wav))
        padded_spectogram = pad2d(spectrogram,40)

        mel_spectrogram = librosa.feature.melspectrogram(wav)
        padded_mel_spectrogram = pad2d(mel_spectrogram,40)

        mfcc = librosa.feature.mfcc(wav)
        padded_mfcc = pad2d(mfcc,40)

        if speaker == test_speaker:
            test_X.append(padded_x)
            test_spectrograms.append(padded_spectogram)
            test_mel_spectrograms.append(padded_mel_spectrogram)
            test_mfccs.append(padded_mfcc)
            test_y.append(digit)
        else:
            train_X.append(padded_x)
            train_spectrograms.append(padded_spectogram)
            train_mel_spectrograms.append(padded_mel_spectrogram)
            train_mfccs.append(padded_mfcc)
            train_y.append(digit)
    except Exception as e:
        print( fname, e)
        raise

train_X = np.vstack(train_X)
train_spectrograms = np.array(train_spectrograms)
train_mel_spectrograms = np.array(train_mel_spectrograms)
train_mfccs = np.array(train_mfccs)
train_y = to_categorical(np.array(train_y))

test_X = np.vstack(test_X)
test_spectrograms = np.array(test_spectrograms)
test_mel_spectrograms = np.array(test_mel_spectrograms)
test_mfccs = np.array(test_mfccs)
test_y = to_categorical(np.array(test_y))


print( 'train_X:', train_X.shape)
print( 'train_spectrograms:', train_spectrograms.shape)
print( 'train_mel_spectrograms:', train_mel_spectrograms.shape)
print( 'train_mfccs:', train_mfccs.shape)
print( 'train_y:', train_y.shape)
print()
print( 'test_X:', test_X.shape)
print( 'test_spectrograms:', test_spectrograms.shape)
print( 'test_mel_spectrograms:', test_mel_spectrograms.shape)
print( 'test_mfccs:', test_mfccs.shape)
print( 'test_y:', test_y.shape)
# Out:
# train_X: (2500, 30000)
# train_spectrograms: (2500, 1025, 40)
# train_mel_spectrograms: (2500, 128, 40)
# train_mfccs: (2500, 20, 40)
# train_y: (2500, 10)
#
# test_X: (500, 30000)
# test_spectrograms: (500, 1025, 40)
# test_mel_spectrograms: (500, 128, 40)
# test_mfccs: (500, 20, 40)
# test_y: (500, 10)

# %%
ip = Input(shape=(train_X[0].shape))
hidden = Dense(128, activation='relu')(ip)
op = Dense(10, activation='softmax')(hidden)
model = Model(ip, op)

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 30000)]           0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3840128
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 3,841,418
# Trainable params: 3,841,418
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(train_X,
          train_y,
          epochs=10,
          batch_size=32,
          validation_data=(test_X, test_y))
# Out:
# Epoch 1/10
# 79/79 [==============================] - 1s 15ms/step - loss: 2.2978 - accuracy: 0.1608 - val_loss: 2.2977 - val_accuracy: 0.1700
# Epoch 2/10
# 79/79 [==============================] - 1s 14ms/step - loss: 1.6776 - accuracy: 0.5440 - val_loss: 2.3040 - val_accuracy: 0.1480
# Epoch 3/10
# 79/79 [==============================] - 1s 14ms/step - loss: 1.2352 - accuracy: 0.6864 - val_loss: 2.3183 - val_accuracy: 0.1460
# Epoch 4/10
# 79/79 [==============================] - 1s 14ms/step - loss: 0.9177 - accuracy: 0.7800 - val_loss: 2.3247 - val_accuracy: 0.1560
# Epoch 5/10
# 79/79 [==============================] - 1s 14ms/step - loss: 0.7130 - accuracy: 0.8352 - val_loss: 2.3475 - val_accuracy: 0.1540
# Epoch 6/10
# 79/79 [==============================] - 1s 14ms/step - loss: 0.5784 - accuracy: 0.8700 - val_loss: 2.3607 - val_accuracy: 0.1440
# Epoch 7/10
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4904 - accuracy: 0.8924 - val_loss: 2.3793 - val_accuracy: 0.1560
# Epoch 8/10
# 79/79 [==============================] - 1s 14ms/step - loss: 0.4242 - accuracy: 0.9088 - val_loss: 2.3947 - val_accuracy: 0.1540
# Epoch 9/10
# 79/79 [==============================] - 1s 14ms/step - loss: 0.3732 - accuracy: 0.9272 - val_loss: 2.4107 - val_accuracy: 0.1660
# Epoch 10/10
# 79/79 [==============================] - 1s 14ms/step - loss: 0.3324 - accuracy: 0.9436 - val_loss: 2.4333 - val_accuracy: 0.1540

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# # SPECTROGRAMS CNN

# %%
train_X_ex = np.expand_dims(train_spectrograms, -1)
test_X_ex = np.expand_dims(test_spectrograms, -1)
print( 'train X shape:', train_X_ex.shape)
print( 'test X shape:', test_X_ex.shape)
# Out:
# train X shape: (2500, 1025, 40, 1)
# test X shape: (500, 1025, 40, 1)

# %%
ip = Input(shape=train_X_ex[0].shape)
m = Conv2D(32, kernel_size=(4, 4), activation='relu', padding='same')(ip)
m = MaxPooling2D(pool_size=(4, 4))(m)
m = Dropout(0.2)(m)
m = Conv2D(64, kernel_size=(4, 4), activation='relu')(ip)
m = MaxPooling2D(pool_size=(4, 4))(m)
m = Dropout(0.2)(m)
m = Flatten()(m)
m = Dense(32, activation='relu')(m)
op = Dense(10, activation='softmax')(m)

model = Model(ip, op)

model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 1025, 40, 1)]     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1022, 37, 64)      1088
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 255, 9, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 255, 9, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 146880)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                4700192
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                330
# =================================================================
# Total params: 4,701,610
# Trainable params: 4,701,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(train_X_ex,
          train_y,
          epochs=10,
          batch_size=32,
          verbose=1,
          validation_data=(test_X_ex, test_y))
# Out:
# Epoch 1/10
# 79/79 [==============================] - 27s 341ms/step - loss: 1.2787 - accuracy: 0.5916 - val_loss: 1.6352 - val_accuracy: 0.5140
# Epoch 2/10
# 79/79 [==============================] - 28s 350ms/step - loss: 0.4534 - accuracy: 0.8580 - val_loss: 1.4545 - val_accuracy: 0.5620
# Epoch 3/10
# 79/79 [==============================] - 27s 346ms/step - loss: 0.3091 - accuracy: 0.9024 - val_loss: 1.3058 - val_accuracy: 0.5280
# Epoch 4/10
# 79/79 [==============================] - 28s 355ms/step - loss: 0.2124 - accuracy: 0.9360 - val_loss: 1.2413 - val_accuracy: 0.5940
# Epoch 5/10
# 79/79 [==============================] - 28s 353ms/step - loss: 0.1598 - accuracy: 0.9572 - val_loss: 1.2382 - val_accuracy: 0.5920
# Epoch 6/10
# 79/79 [==============================] - 28s 352ms/step - loss: 0.1283 - accuracy: 0.9648 - val_loss: 1.1908 - val_accuracy: 0.5740
# Epoch 7/10
# 79/79 [==============================] - 28s 351ms/step - loss: 0.1139 - accuracy: 0.9664 - val_loss: 1.2505 - val_accuracy: 0.5640
# Epoch 8/10
# 79/79 [==============================] - 27s 342ms/step - loss: 0.0701 - accuracy: 0.9820 - val_loss: 1.2658 - val_accuracy: 0.5480
# Epoch 9/10
# 79/79 [==============================] - 27s 343ms/step - loss: 0.1366 - accuracy: 0.9596 - val_loss: 1.5045 - val_accuracy: 0.5360
# Epoch 10/10
# 79/79 [==============================] - 27s 344ms/step - loss: 0.1222 - accuracy: 0.9636 - val_loss: 1.3727 - val_accuracy: 0.5000

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# # MEL SPECTROGRAM CNN

# %%
train_X_ex = np.expand_dims(train_mel_spectrograms, -1)
test_X_ex = np.expand_dims(test_mel_spectrograms, -1)
print( 'train X shape:', train_X_ex.shape)
print( 'test X shape:', test_X_ex.shape)
# Out:
# train X shape: (2500, 128, 40, 1)
# test X shape: (500, 128, 40, 1)

# %%
ip = Input(shape=train_X_ex[0].shape)
m = Conv2D(32, kernel_size=(4, 4), activation='relu', padding='same')(ip)
m = MaxPooling2D(pool_size=(4, 4))(m)
m = Dropout(0.2)(m)
m = Conv2D(64, kernel_size=(4, 4), activation='relu')(ip)
m = MaxPooling2D(pool_size=(4, 4))(m)
m = Dropout(0.2)(m)
m = Flatten()(m)
m = Dense(32, activation='relu')(m)
op = Dense(10, activation='softmax')(m)

model = Model(ip, op)

model.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 128, 40, 1)]      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 125, 37, 64)       1088
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 31, 9, 64)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 31, 9, 64)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 17856)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                571424
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                330
# =================================================================
# Total params: 572,842
# Trainable params: 572,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(train_X_ex,
          train_y,
          epochs=10,
          batch_size=32,
          verbose=1,
          validation_data=(test_X_ex, test_y))
# Out:
# Epoch 1/10
# 79/79 [==============================] - 3s 42ms/step - loss: 1.7391 - accuracy: 0.4764 - val_loss: 2.2696 - val_accuracy: 0.1420
# Epoch 2/10
# 79/79 [==============================] - 3s 43ms/step - loss: 0.9639 - accuracy: 0.6988 - val_loss: 2.2703 - val_accuracy: 0.1880
# Epoch 3/10
# 79/79 [==============================] - 3s 42ms/step - loss: 0.7573 - accuracy: 0.7696 - val_loss: 2.1780 - val_accuracy: 0.2840
# Epoch 4/10
# 79/79 [==============================] - 3s 43ms/step - loss: 0.6102 - accuracy: 0.8056 - val_loss: 2.2130 - val_accuracy: 0.2800
# Epoch 5/10
# 79/79 [==============================] - 3s 42ms/step - loss: 0.6053 - accuracy: 0.8196 - val_loss: 2.2039 - val_accuracy: 0.1980
# Epoch 6/10
# 79/79 [==============================] - 3s 42ms/step - loss: 0.6582 - accuracy: 0.8368 - val_loss: 2.4103 - val_accuracy: 0.1780
# Epoch 7/10
# 79/79 [==============================] - 3s 42ms/step - loss: 0.7720 - accuracy: 0.7904 - val_loss: 2.3952 - val_accuracy: 0.2160
# Epoch 8/10
# 79/79 [==============================] - 3s 41ms/step - loss: 0.4648 - accuracy: 0.8632 - val_loss: 2.2992 - val_accuracy: 0.3060
# Epoch 9/10
# 79/79 [==============================] - 3s 42ms/step - loss: 0.4581 - accuracy: 0.8728 - val_loss: 2.3620 - val_accuracy: 0.2980
# Epoch 10/10
# 79/79 [==============================] - 3s 43ms/step - loss: 0.3838 - accuracy: 0.8852 - val_loss: 2.3799 - val_accuracy: 0.2200

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# # MFCC CNN

# %%
train_X_ex = np.expand_dims(train_mfccs, -1)
test_X_ex = np.expand_dims(test_mfccs, -1)
print( 'train X shape:', train_X_ex.shape)
print( 'test X shape:', test_X_ex.shape)
# Out:
# train X shape: (2500, 20, 40, 1)
# test X shape: (500, 20, 40, 1)

# %%
ip = Input(shape=train_X_ex[0].shape)
m = Conv2D(64, kernel_size=(4, 4), activation='relu')(ip)
m = MaxPooling2D(pool_size=(4, 4))(m)
# m = Conv2D(128, kernel_size=(2, 2), activation='relu')(ip)
# m = MaxPooling2D(pool_size=(2, 2))(m)
m = Flatten()(m)
m = Dense(32, activation='relu')(m)
op = Dense(10, activation='softmax')(m)

model = Model(ip, op)

model.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 20, 40, 1)]       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 17, 37, 64)        1088
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 9, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                73760
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                330
# =================================================================
# Total params: 75,178
# Trainable params: 75,178
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(train_X_ex,
          train_y,
          epochs=100,
          batch_size=32,
          verbose=0,
          validation_data=(test_X_ex, test_y))

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
